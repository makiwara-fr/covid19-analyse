# %% [markdown]
# # Analyse COVID-19

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Fetching calculated data

# %%
df_dataset = pd.read_csv('dataset.csv', index_col=0)

# %%
df_dataset
# Out:
#              country        date  cases  population     density      size  \
# 53           Albania  2020-01-22      0    2877.800  105.029197   27400.0
# 54           Albania  2020-01-23      0    2877.800  105.029197   27400.0
# 55           Albania  2020-01-24      0    2877.800  105.029197   27400.0
# 56           Albania  2020-01-25      0    2877.800  105.029197   27400.0
# 57           Albania  2020-01-26      0    2877.800  105.029197   27400.0
# ...              ...         ...    ...         ...         ...       ...
# 7362  United Kingdom  2020-03-10    384   67886.004  280.601844  241930.0
# 7363  United Kingdom  2020-03-11    459   67886.004  280.601844  241930.0
# 7364  United Kingdom  2020-03-12    459   67886.004  280.601844  241930.0
# 7365  United Kingdom  2020-03-13    801   67886.004  280.601844  241930.0
# 7366  United Kingdom  2020-03-14   1143   67886.004  280.601844  241930.0
#
#          ratio  start_date  age
# 53    0.000000  2020-03-12  -50
# ...

# %% [markdown]
# # Dynamics

# %%
df_dynamics = df_dataset[['country','ratio','age']].

# %%
df_dynamics_t = df_dynamics.pivot(index='age',columns='country',values='ratio')

# %%
df_dynamics_plot = df_dynamics_t.loc[:,['China','US','France', 'Italy','Spain','Germany']]

# %%
ax=df_dynamics_plot.plot(kind='line', figsize=(16,10))
plt.title("Comparison infection rate per countries", fontsize=18)
plt.xlabel("Numbers of days since beg of crisis")
plt.ylabel("Number of infected people per 100 000 inhabitants")
plt.grid()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.savefig("save.png")
plt.show()

# %%
# Out:
# country  Albania  Andorra  Antigua and Barbuda  Armenia  Aruba  Australia  \
# age
# -52          NaN      NaN                  NaN      0.0    NaN        NaN
# -51          NaN      NaN                  0.0      0.0    0.0        NaN
# -50          0.0      NaN                  0.0      0.0    0.0        NaN
# -49          0.0      NaN                  0.0      0.0    0.0   0.000000
# -48          0.0      NaN                  0.0      0.0    0.0   0.000000
# -47          0.0      NaN                  0.0      0.0    0.0   0.000000
# -46          0.0      NaN                  0.0      0.0    0.0   0.000000
# -45          0.0      NaN                  0.0      0.0    0.0   0.015686
# -44          0.0      NaN                  0.0      0.0    0.0   0.019608
# -43          0.0      NaN                  0.0      0.0    0.0   0.019608
# -42          0.0      NaN                  0.0      0.0    0.0   0.023530
# -41          0.0      NaN                  0.0      0.0    0.0   0.035294
# ...
