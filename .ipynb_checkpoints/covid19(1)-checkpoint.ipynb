# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Infection

# %%
#COVID-19/who_covid_19_situation_reports/who_covid_19_sit_rep_time_series/
flow = 'csse'
#flow = "who"


#!cd "COVID-19"
#    !git pull https://github.com/CSSEGISandData/COVID-19.git master
# !cd COVID-19 && git pull origin master
# Out:
# From https://github.com/CSSEGISandData/COVID-19
#  * branch            master     -> FETCH_HEAD
# Already up to date.

# %% [markdown]
# ## WHO flow
# We get WHO data

# %%
if flow == 'who':
    df_corona = pd.read_csv("./who_covid_19_sit_rep_time_series.csv")
#df_corona = pd.read_csv("./COVID-19/who_covid_19_situation_reports/who_covid_19_sit_rep_time_series/who_covid_19_sit_rep_time_series.csv")

# %%
if flow == 'who':
    df_corona = df_corona.groupby(by="Country/Region").sum()
    df_corona.fillna(0, inplace=True)
    df_corona.index.name = None
    df_corona.columns = pd.to_datetime(df_corona.columns)

# %% [markdown]
# ## csse flow

# %%
if flow == "csse":
    df_corona = pd.read_csv("./COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv")

# %%
if flow == "csse":
    df_corona.drop(['Lat','Long'], axis=1,inplace=True)

# %%
if flow == "csse":
    df_corona = df_corona.groupby(by="Country/Region").sum()
    df_corona.fillna(0, inplace=True)
    df_corona.index.name = None
    df_corona.columns = pd.to_datetime(df_corona.columns)
    df_corona.rename(index={'Mainland China':'China'},inplace=True)

# %%
df_corona.head(10)
# Out:
#              2020-01-22  2020-01-23  2020-01-24  2020-01-25  2020-01-26  \
# Afghanistan           0           0           0           0           0
# Albania               0           0           0           0           0
# Algeria               0           0           0           0           0
# Andorra               0           0           0           0           0
# Argentina             0           0           0           0           0
# Armenia               0           0           0           0           0
# Australia             0           0           0           0           4
# Austria               0           0           0           0           0
# Azerbaijan            0           0           0           0           0
# Bahrain               0           0           0           0           0
#
#              2020-01-27  2020-01-28  2020-01-29  2020-01-30  2020-01-31  ...  \
# Afghanistan           0           0           0           0           0  ...
# Albania               0           0           0           0           0  ...
# Algeria               0           0           0           0           0  ...
# Andorra               0           0           0           0           0  ...
# Argentina             0           0           0           0           0  ...
# Armenia               0           0           0           0           0  ...
# Australia             5           5           6           9           9  ...
# Austria               0           0           0           0           0  ...
# Azerbaijan            0           0           0           0           0  ...
# Bahrain               0           0           0           0           0  ...
#
#              2020-03-03  2020-03-04  2020-03-05  2020-03-06  2020-03-07  \
# Afghanistan           1           1           1           1           1
# Albania               0           0           0           0           0
# Algeria               5          12          12          17          17
# Andorra               1           1           1           1           1
# Argentina             1           1           1           2           8
# Armenia               1           1           1           1           1
# Australia            39          52          55          60          63
# Austria              21          29          41          55          79
# Azerbaijan            3           3           6           6           9
# Bahrain              49          52          55          60          85
#
#              2020-03-08  2020-03-09  2020-03-10  2020-03-11  2020-03-12
# Afghanistan           4           4           5           7           7
# Albania               0           2          10          12          23
# Algeria              19          20          20          20          24
# Andorra               1           1           1           1           1
# Argentina            12          12          17          19          19
# Armenia               1           1           1           1           4
# Australia            76          91         107         128         128
# Austria             104         131         182         246         302
# Azerbaijan            9           9          11          11          11
# Bahrain              85          95         110         195         195
#
# [10 rows x 51 columns]

# %%
df_corona.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Argentina', 'Armenia',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahrain',
#        ...
#        'Taiwan*', 'Thailand', 'Togo', 'Tunisia', 'Turkey', 'US', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'Vietnam'],
#       dtype='object', length=116)

# %% [markdown]
# ## back to generic

# %%
df_corona.shape
# Out:
# (116, 51)

# %%
# Listing all the dates in the columns
dates_list = list(df_corona.columns)

# %% [markdown]
# # World population

# %%
df_wp_temp = pd.read_excel("./population_world.xlsx", sheet_name = 'ESTIMATES', skiprows= range(0,16))

# %%
df_wp_temp.drop(['Index','Variant', 'Notes','Country code', 'Parent code'], inplace=True, axis=1)

# %%
df_wp = df_wp_temp[df_wp_temp['Type'] == 'Country/Area']

# %%
def retreat(df):
    
    output = df.rename(columns={'Region, subregion, country or area *' : 'Country'})
    output.set_index("Country", inplace=True)
    output.rename(index={'Republic of Korea' : 'South Korea', 'Iran (Islamic Republic of)': 'Iran', 'United States of America' : 'US'}, inplace=True)
    output.sort_values(by='2020', ascending=False, inplace=True)
    return output
#df_wp.drop('index', axis=1, inplace=True)

# %%
df_wp =retreat(df_wp)

# %%
#df_wp.head(30)

# %% [markdown]
# ## Population density

# %%
df_dens_temp = pd.read_excel("./WPP2019_POP_F06_POPULATION_DENSITY.xlsx", sheet_name = 'ESTIMATES', skiprows= range(0,16))

# %%
df_dens_temp = df_dens_temp[df_dens_temp['Type'] == 'Country/Area']

# %%
df_dens_temp = retreat(df_dens_temp)

# %%
df_dens_temp
# Out:
#                              Index    Variant Notes  Country code  \
# Country
# Monaco                         281  Estimates   NaN           492
# China, Macao SAR               130  Estimates    11           446
# Singapore                      144  Estimates   NaN           702
# China, Hong Kong SAR           129  Estimates    10           344
# Gibraltar                      262  Estimates    14           292
# ...                            ...        ...   ...           ...
# Namibia                         61  Estimates   NaN           516
# Western Sahara                  89  Estimates   NaN           732
# Mongolia                       134  Estimates   NaN           496
# Falkland Islands (Malvinas)    194  Estimates    17           238
# Greenland                      287  Estimates    26           304
#
#                                      Type  Parent code       1950       1951  \
# Country
# Monaco                       Country/Area          926    13422.8    13009.4
# China, Macao SAR             Country/Area          906       6571    6705.35
# Singapore                    Country/Area          920    1460.14    1525.42
# China, Hong Kong SAR         Country/Area          906       1880    1959.75
# Gibraltar                    Country/Area          925     2203.2     2228.7
# ...                                   ...          ...        ...        ...
# Namibia                      Country/Area          913   0.624783   0.636426
# Western Sahara               Country/Area          912  0.0517406  0.0603534
# Mongolia                     Country/Area          906   0.502201   0.510786
# Falkland Islands (Malvinas)  Country/Area          931    0.18521    0.18447
# Greenland                    Country/Area          918   0.056019  0.0571714
#
#                                   1952       1953  ...      2011      2012  \
# Country                                            ...
# Monaco                         12806.7    12784.6  ...   24177.9   24469.1
# China, Macao SAR               6731.37    6665.28  ...   18422.5   18864.1
# Singapore                       1599.9    1682.26  ...   7519.49   7670.67
# China, Hong Kong SAR           2047.71    2143.54  ...   6672.95   6711.28
# Gibraltar                       2248.9     2263.2  ...    3360.8    3365.3
# ...                                ...        ...  ...       ...       ...
# Namibia                       0.648815   0.661857  ...   2.61961   2.66586
# Western Sahara               0.0660714  0.0704023  ...   1.83329   1.86381
# Mongolia                      0.520046   0.529795  ...   1.78323   1.81821
# Falkland Islands (Malvinas)    0.18332   0.182169  ...  0.235251  0.231964
# Greenland                    0.0583165  0.0596053  ...  0.137788  0.137598
#
#                                  2013      2014      2015      2016      2017  \
# Country
# Monaco                        24764.4     25047   25317.4   25550.3   25766.4
# China, Macao SAR                19310   19739.5   20136.9   20495.8     20822
# Singapore                     7791.05   7893.75   7988.78   8076.61   8154.35
# China, Hong Kong SAR          6751.22   6794.92    6843.8   6898.61    6958.4
# Gibraltar                      3369.4    3372.6    3374.2    3373.8    3372.3
# ...                               ...       ...       ...       ...       ...
# Namibia                        2.7129   2.76139   2.81177   2.86417   2.91832
# Western Sahara                1.89796   1.93603   1.97824   2.02535   2.07751
# Mongolia                      1.85495    1.8925   1.93004   1.96733   2.00429
# Falkland Islands (Malvinas)  0.229499  0.229006  0.233032  0.240427  0.252588
# Greenland                    0.137439  0.137369  0.137357   0.13743  0.137588
#
#                                  2018      2019      2020
# Country
# Monaco                        25961.1   26152.3   26338.3
# China, Macao SAR              21124.8   21419.6   21717.1
# Singapore                        8225   8291.92   8357.63
# China, Hong Kong SAR          7020.69   7082.05   7139.99
# Gibraltar                      3371.5    3370.6    3369.1
# ...                               ...       ...       ...
# Namibia                        2.9738   3.02995    3.0863
# Western Sahara                2.13307   2.18969    2.2456
# Mongolia                      2.04061   2.07598   2.11018
# Falkland Islands (Malvinas)    0.2659  0.277075  0.286196
# Greenland                    0.137812  0.138044  0.138316
#
# [235 rows x 77 columns]

# %%
df_dens = df_dens_temp['2020']

# %%
df_dens['US']
# Out:
# 36.1853557615153

# %% [markdown]
# # Calculation of infection ratio per population
# Enrichment of data with population figures from UN
# End results is *df_corona_ratio*
# We filter on countries that have been actually infected getting top *number_countries* at date

# %%
number_countries = 15

# %%
df_corona = df_corona.join(df_wp['2020'], how="left")

# %%
df_corona.rename(columns={'2020': 'population'}, inplace=True)
df_corona.sort_values(by='population', inplace=True, ascending=False)
# we keep the biggest countries
df_corona = df_corona.head(30)
# we keep the max of contamination
df_corona = df_corona.loc[list(df_corona[max(dates_list)].sort_values(ascending=False).head(number_countries).index.values),:]

# %%
df_corona.shape
# Out:
# (15, 52)

# %%
df_corona.head(30)
# Out:
#                 2020-01-22 00:00:00  2020-01-23 00:00:00  2020-01-24 00:00:00  \
# China                           548                  643                  920
# Italy                             0                    0                    0
# Iran                              0                    0                    0
# France                            0                    0                    2
# Spain                             0                    0                    0
# Germany                           0                    0                    0
# US                                1                    1                    2
# Japan                             2                    1                    2
# United Kingdom                    0                    0                    0
# Canada                            0                    0                    0
# India                             0                    0                    0
# Iraq                              0                    0                    0
# Thailand                          2                    3                    5
# Egypt                             0                    0                    0
# Philippines                       0                    0                    0
#
#                 2020-01-25 00:00:00  2020-01-26 00:00:00  2020-01-27 00:00:00  \
# Egypt                    0          0          0           0           0  ...
# Philippines              0          0          0    0.002721    0.002721  ...
#
#                2020-03-03 2020-03-04 2020-03-05 2020-03-06 2020-03-07  \
# China             523.515     524.33    525.315    526.313    526.835
# Italy             12.1719    15.0276    18.7687    22.5536    28.6201
# Iran               45.293     56.655     68.114    92.0402    112.903
# France            1.71129    2.41593    3.18769    5.50296      7.986
# Spain             1.76029    2.36839    2.76312    4.26737    5.33421
# Germany          0.815404    1.08998    2.00523    2.78735    3.32402
# US                3.26099    4.11769     5.9969     7.2405    11.1095
# Japan            0.844541   0.954072    1.03766    1.21061    1.32878
# United Kingdom   0.181752   0.306484   0.413397   0.584458     0.7377
# Canada            7.22813    7.95095     8.9147    11.8059    13.0106
# India           0.0107724  0.0603254  0.0646344  0.0667888  0.0732523
# Iraq             0.345534   0.377928   0.377928   0.431917   0.583089
# Thailand         0.314732   0.314732   0.344009   0.351328   0.365967
# Egypt           0.0194548  0.0194548  0.0291823   0.145911   0.145911
# Philippines      0.008163   0.008163   0.008163   0.013605   0.016326
#
#                2020-03-08 2020-03-09 2020-03-10 2020-03-11 2020-03-12
# China              527.18    527.422    527.598     527.82    527.891
# Italy             35.8785    44.6207    49.3737    60.6262    60.6262
# Iran              127.309    138.846    155.927    174.502    195.345
# France            9.47079    10.1671    14.9905    19.1597    19.1597
# Spain             7.17985    11.4472     18.083     24.292     24.292
# Germany           4.32663    4.89242    6.06145    7.93771    8.64495
# US                14.3152    16.1115    26.5024    35.4011    45.9578
# Japan             1.44696     1.4729    1.67467    1.84185    1.84185
# United Kingdom   0.976473    1.14753    1.36849    1.63577    1.63577
# Canada              15.42    18.5522    19.0341    26.0213    28.1897
# India           0.0840247  0.0926426   0.120651   0.133578   0.157277
# Iraq             0.647876   0.647876   0.766653   0.766653   0.766653
# Thailand         0.365967   0.365967   0.387925   0.431841   0.512354
# Egypt            0.476644   0.535008   0.573918   0.583645   0.651737
# Philippines       0.02721    0.05442   0.089793   0.133329   0.141492
#
# [15 rows x 51 columns]

# %%
df_corona_density_ratio.shape
# Out:
# (15, 51)

# %% [markdown]
# # Start of the crisis

# %%
df_corona_ratio.head(15).transpose().plot(figsize=(16,10))

plt.show()

# %%
import numpy as np
import matplotlib as mplt
def log_plus_un(x):
    return np.log(x+1)


#np.log((df_corona_density_ratio.transpose()+1).astype(float))
(df_corona_density_ratio.transpose()+1).astype(float).apply(log_plus_un).plot(kind='line', figsize=(16,10))
plt.title('Corona case per population density')
plt.show()

# %% [markdown]
# ## The starting dates
# *serie_crisis_start* is a serie of the start of the crisis (above ratio) per country

# %%
ratio_start = 0.5
ratio_start_density = 3.6

# %%
df_tmp = df_corona_ratio > ratio_start
df_tmp_dens = df_corona_density_ratio > ratio_start_density

# %%
df_tmp = df_tmp.cumsum(axis=1)
df_tmp_dens = df_tmp_dens.cumsum(axis=1)

# %%
# look where we start index when we reach 1
serie_crisis_start = (df_tmp == 1).idxmax(axis=1)
serie_crisis_start_dens = (df_tmp_dens == 1).idxmax(axis=1)

# Iran             2020-02-29
# China            2020-01-30
# Spain            2020-03-05
# France           2020-03-05
# Germany          2020-03-05
# United Kingdom   2020-03-10
# Japan            2020-03-11
# US               2020-03-12
# Canada           2099-01-01
# Iraq             2099-01-01
# Thailand         2099-01-01
# Egypt            2099-01-01
# Philippines      2099-01-01
# India            2099-01-01
# dtype: datetime64[ns]

# %%
serie_crisis_start_dens
# Out:
# Country
# China            2020-01-23
# Italy            2020-02-28
# Iran             2020-02-27
# France           2020-03-06
# Spain            2020-03-06
# Germany          2020-03-08
# US               2020-03-04
# Japan            2099-01-01
# United Kingdom   2099-01-01
# Canada           2020-02-29
# India            2099-01-01
# Iraq             2099-01-01
# Thailand         2099-01-01
# Egypt            2099-01-01
# Philippines      2099-01-01
# dtype: datetime64[ns]

# %% [markdown]
# ## Define a matrix with age of crisis as index

# %%
import numpy as np

# %%
duration = range(-30,100)
df_corona_ratio.shape[0], len(duration)
np.zeros((df_corona_ratio.shape[0], len(duration)))
df_crisis_age = pd.DataFrame(columns = duration, index=df_corona_ratio.index)
#df_crisis_age = pd.DataFrame(np.empty((df_corona_ratio.shape[0], len(duration))), columns = duration)
#df_crisis_age.set_index(df_corona_ratio.index, inplace=True)
df_crisis_age.shape
# Out:
# (15, 130)

# %%
duration = range(-30,100)

df_crisis_age_dens = pd.DataFrame(columns = duration, index=df_corona_density_ratio.index)
#df_crisis_age = pd.DataFrame(np.empty((df_corona_ratio.shape[0], len(duration))), columns = duration)
#df_crisis_age.set_index(df_corona_ratio.index, inplace=True)
df_crisis_age_dens.shape
# Out:
# (15, 130)

# %% [markdown]
# ## Populate the df_crisis_age
#
# We loop over the dates series and age and populate the *df_crisis_age*

# %%
for index, value in serie_crisis_start.iteritems():
    i = 0
    for d in df_corona_ratio.columns.values:
        i = (d - value).days
        if i in duration:
            #print(index, i)
            
            df_crisis_age.loc[index, i] = df_corona_ratio.loc[index, d]
df_crisis_age.index.name = 'Country'
df_crisis_age
# Out:
#                        -30         -29         -28         -27         -26  \
# Country
# Italy                    0           0           0           0           0
# Iran                     0           0           0           0           0
# China                  NaN         NaN         NaN         NaN         NaN
# Spain           0.00213882  0.00213882  0.00213882  0.00213882  0.00213882
# France          0.00919209  0.00919209  0.00919209  0.00919209   0.0168522
# Germany          0.0143226   0.0143226   0.0143226   0.0155161   0.0155161
# United Kingdom  0.00441917   0.0117845   0.0117845   0.0132575   0.0132575
# Japan            0.0205572   0.0205572   0.0221385   0.0221385   0.0229292
# US              0.00362535  0.00362535  0.00392746  0.00392746  0.00392746
# Canada                 NaN         NaN         NaN         NaN         NaN
# Iraq                   NaN         NaN         NaN         NaN         NaN
# Thailand               NaN         NaN         NaN         NaN         NaN
# Egypt                  NaN         NaN         NaN         NaN         NaN
# Philippines            NaN         NaN         NaN         NaN         NaN
# India                  NaN         NaN         NaN         NaN         NaN
#
#                        -25         -24         -23         -22         -21  \
# Country
# Italy           0.00330787  0.00330787  0.00330787  0.00330787  0.00330787
# Iran                     0           0           0           0           0
# China                  NaN         NaN         NaN         NaN         NaN
# Spain           0.00427764  0.00427764  0.00427764  0.00427764  0.00427764
# France           0.0168522   0.0168522   0.0168522   0.0168522   0.0168522
# Germany          0.0167096   0.0167096   0.0190967   0.0190967   0.0190967
# United Kingdom   0.0132575   0.0132575   0.0132575   0.0132575   0.0132575
# Japan            0.0339984    0.046649   0.0521836   0.0585089   0.0664155
# US              0.00392746  0.00392746  0.00392746  0.00392746  0.00392746
# Canada                 NaN         NaN         NaN         NaN         NaN
# Iraq                   NaN         NaN         NaN         NaN         NaN
# Thailand               NaN         NaN         NaN         NaN         NaN
# Egypt                  NaN         NaN         NaN         NaN         NaN
# Philippines            NaN         NaN         NaN         NaN         NaN
# India                  NaN         NaN         NaN         NaN         NaN
#
#                 ...   90   91   92   93   94   95   96   97   98   99
# Country         ...
# Italy           ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Iran            ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# China           ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Spain           ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# France          ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Germany         ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# United Kingdom  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Japan           ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# US              ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Canada          ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Iraq            ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Thailand        ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Egypt           ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Philippines     ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# India           ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [15 rows x 130 columns]

# %%
for index, value in serie_crisis_start_dens.iteritems():
    i = 0
    for d in df_corona_density_ratio.columns.values:
        i = (d - value).days
        if i in duration:
            #print(index, i)
            
            df_crisis_age_dens.loc[index, i] = df_corona_density_ratio.loc[index, d]
df_crisis_age_dens.index.name = 'Country'
df_crisis_age_dens
# Out:
#                       -30        -29         -28         -27         -26  \
# Country
# China                 NaN        NaN         NaN         NaN         NaN
# Italy                   0          0  0.00972978  0.00972978  0.00972978
# Iran                    0          0           0           0           0
# France          0.0503319  0.0503319   0.0503319   0.0922752   0.0922752
# Spain           0.0106684  0.0106684   0.0106684   0.0106684   0.0213369
# Germany         0.0540829  0.0540829   0.0582431   0.0582431   0.0665636
# US                0.30399    0.30399     0.30399     0.30399     0.30399
# Japan                 NaN        NaN         NaN         NaN         NaN
# United Kingdom        NaN        NaN         NaN         NaN         NaN
# Canada           0.481875   0.963751    0.963751    0.963751    0.963751
# India                 NaN        NaN         NaN         NaN         NaN
# Iraq                  NaN        NaN         NaN         NaN         NaN
# Thailand              NaN        NaN         NaN         NaN         NaN
# Egypt                 NaN        NaN         NaN         NaN         NaN
# Philippines           NaN        NaN         NaN         NaN         NaN
#
#                        -25         -24         -23         -22        -21  \
# Country
# China                  NaN         NaN         NaN         NaN        NaN
# Italy           0.00972978  0.00972978  0.00972978  0.00972978  0.0145947
# Iran                     0           0           0           0          0
# France           0.0922752   0.0922752   0.0922752   0.0922752  0.0922752
# Spain            0.0213369   0.0213369   0.0213369   0.0213369  0.0213369
# Germany          0.0665636   0.0665636   0.0665636   0.0665636  0.0665636
# US                 0.30399     0.30399     0.30399    0.331626   0.331626
# Japan                  NaN         NaN         NaN         NaN        NaN
# United Kingdom         NaN         NaN         NaN         NaN        NaN
# Canada            0.963751     1.20469     1.20469     1.68656    1.68656
# India                  NaN         NaN         NaN         NaN        NaN
# Iraq                   NaN         NaN         NaN         NaN        NaN
# Thailand               NaN         NaN         NaN         NaN        NaN
# Egypt                  NaN         NaN         NaN         NaN        NaN
# Philippines            NaN         NaN         NaN         NaN        NaN
#
#                 ...   90   91   92   93   94   95   96   97   98   99
# Country         ...
# China           ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Italy           ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Iran            ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# France          ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Spain           ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Germany         ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# US              ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Japan           ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# United Kingdom  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Canada          ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# India           ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Iraq            ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Thailand        ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Egypt           ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Philippines     ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [15 rows x 130 columns]

# %%
df_crisis_age_dens[0]
# Out:
# Country
# China             4.19407
# Italy             4.32002
# Iran              4.75034
# France            5.50296
# Spain             4.26737
# Germany           4.32663
# US                4.11769
# Japan                 NaN
# United Kingdom        NaN
# Canada            4.81875
# India                 NaN
# Iraq                  NaN
# Thailand              NaN
# Egypt                 NaN
# Philippines           NaN
# Name: 0, dtype: object

# %% [markdown]
# # Results

# %%
df_crisis_age_plot = df_crisis_age.transpose()

# %%
ax = df_crisis_age_plot.plot(figsize=(15,8))
plt.title("Comparison infection rate per countries", fontsize=18)
plt.xlabel("Numbers of days since beg of crisis")
plt.ylabel("Number of infected people per 100 000 inhabitants")
plt.grid()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.savefig("save.png")
plt.show()

# %%
df_crisis_age_dens_plot = df_crisis_age_dens.transpose()

# %%
ax = df_crisis_age_dens_plot.astype(float).apply(log_plus_un).plot(figsize=(15,8))
plt.title("Comparison infection rate per countries", fontsize=18)
plt.xlabel("Numbers of days since beg of crisis")
plt.ylabel("Log of Number of infected people per inhabitants per km2 plus 1")
plt.grid()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.savefig("save.png")
plt.show()

# %%
df_crisis_age_dens_plot.loc['China',:]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'China'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-369-b876a0e5e0a8> in <module>
# ----> 1 df_crisis_age_dens_plot.loc['China',:]
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1758                 except (KeyError, IndexError, AttributeError):
#    1759                     pass
# -> 1760             return self._getitem_tuple(key)
#    1761         else:
#    1762             # we by definition only have the 0th axis
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1268     def _getitem_tuple(self, tup: Tuple):
#    1269         try:
# -> 1270             return self._getitem_lowerdim(tup)
#    1271         except IndexingError:
#    1272             pass
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#    1385         for i, key in enumerate(tup):
#    1386             if is_label_like(key) or isinstance(key, tuple):
# -> 1387                 section = self._getitem_axis(key, axis=i)
#    1388
#    1389                 # we have yielded a scalar ?
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1961         # fall thru to straight lookup
#    1962         self._validate_key(key, axis)
# -> 1963         return self._get_label(key, axis=axis)
#    1964
#    1965
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     622             raise IndexingError("no slices here, handle elsewhere")
#     623
# --> 624         return self.obj._xs(label, axis=axis)
#     625
#     626     def _get_loc(self, key: int, axis: int):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3534             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3535         else:
# -> 3536             loc = self.index.get_loc(key)
#    3537
#    3538             if isinstance(loc, np.ndarray):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     351             except ValueError:
#     352                 raise KeyError(key)
# --> 353         return super().get_loc(key, method=method, tolerance=tolerance)
#     354
#     355     @Appender(_index_shared_docs["get_indexer"])
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'China'

# %%
(np.exp(6.2)-1)*112
# Out:
# 55075.89260244471

# %%
df_dens['China']
# Out:
# 153.311826289375

# %%
(np.exp(6.2)-1)*153
# Out:
# 75237.60328726821

# %%
df_corona_density_ratio.loc['China',max(dates_list)]
# Out:
# 527.8914351150016

# %%
527*112
# Out:
# 59024
